# %%
import pandas as pd
import numpy as np

bike_Stop = pd.read_csv('공공자전거_대여소_정보_22.06.csv',encoding='CP949')

bike_Stop.head()
# Out:
#    대여소번호   보관소(대여소)명  자치구               상세주소         위도          경도  \
# 0    102  망원역 1번출구 앞  마포구  서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 1    103  망원역 2번출구 앞  마포구  서울특별시 마포구 월드컵로 79  37.554951  126.910835
# 2    104  합정역 1번출구 앞  마포구   서울특별시 마포구 양화로 59  37.550629  126.914986
# 3    105  합정역 5번출구 앞  마포구   서울특별시 마포구 양화로 48  37.550007  126.914825
# 4    106  합정역 7번출구 앞  마포구    서울특별시 마포구 독막로 4  37.548645  126.912826
#
#         설치시기  거치대수_LCD  거치대수_QR 운영방식
# 0   2022.5.3       NaN     15.0   QR
# 1   2022.5.3       NaN     14.0   QR
# 2  2022.5.12       NaN     13.0   QR
# 3   2015.9.6       NaN      5.0   QR
# 4  2022.5.12       NaN     12.0   QR

# %%
bike_Stop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소번호      2653 non-null   int64
#  1   보관소(대여소)명  2653 non-null   object
#  2   자치구        2653 non-null   object
#  3   상세주소       2653 non-null   object
#  4   위도         2653 non-null   float64
#  5   경도         2653 non-null   float64
#  6   설치시기       2652 non-null   object
#  7   거치대수_LCD   1290 non-null   float64
#  8   거치대수_QR    1378 non-null   float64
#  9   운영방식       2653 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 207.4+ KB

# %%
bike_Stop.describe()
# Out:
#              대여소번호           위도           경도     거치대수_LCD      거치대수_QR
# count  2653.000000  2653.000000  2653.000000  1290.000000  1378.000000
# mean   2183.524312    37.547472   126.991584    12.484496    11.772859
# std    1464.033115     0.051972     0.092706     4.774528     5.475893
# min     102.000000    37.430977   126.798599     5.000000     4.000000
# 25%     950.000000    37.505455   126.914833    10.000000    10.000000
# 50%    1928.000000    37.546535   127.002457    10.000000    10.000000
# 75%    3545.000000    37.577316   127.064446    15.000000    14.000000
# max    5855.000000    37.691013   127.180641    46.000000    55.000000

# %%
bike_Stop.isnull()
# Out:
#       대여소번호  보관소(대여소)명    자치구   상세주소     위도     경도   설치시기  거치대수_LCD  거치대수_QR  \
# 0     False      False  False  False  False  False  False      True    False
# 1     False      False  False  False  False  False  False      True    False
# 2     False      False  False  False  False  False  False      True    False
# 3     False      False  False  False  False  False  False      True    False
# 4     False      False  False  False  False  False  False      True    False
# ...     ...        ...    ...    ...    ...    ...    ...       ...      ...
# 2648  False      False  False  False  False  False  False      True    False
# 2649  False      False  False  False  False  False  False      True    False
# 2650  False      False  False  False  False  False  False      True    False
# 2651  False      False  False  False  False  False  False      True    False
# 2652  False      False  False  False  False  False  False      True    False
#
#        운영방식
# 0     False
# 1     False
# ...

# %%
bike_Stop.isnull().sum()
# Out:
# 대여소번호           0
# 보관소(대여소)명       0
# 자치구             0
# 상세주소            0
# 위도              0
# 경도              0
# 설치시기            1
# 거치대수_LCD     1363
# 거치대수_QR      1275
# 운영방식            0
# dtype: int64

# %%
bike_Stop.fillna(0, inplace=True)

bike_Stop.isnull().sum()
# Out:
# 대여소번호        0
# 보관소(대여소)명    0
# 자치구          0
# 상세주소         0
# 위도           0
# 경도           0
# 설치시기         0
# 거치대수_LCD     0
# 거치대수_QR      0
# 운영방식         0
# dtype: int64

# %%
bike_Stop['총 거치대수'] = bike_Stop['거치대수_LCD'] + bike_Stop['거치대수_QR'] 
print(bike_Stop.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소번호      2653 non-null   int64
#  1   보관소(대여소)명  2653 non-null   object
#  2   자치구        2653 non-null   object
#  3   상세주소       2653 non-null   object
#  4   위도         2653 non-null   float64
#  5   경도         2653 non-null   float64
#  6   설치시기       2653 non-null   object
#  7   거치대수_LCD   2653 non-null   float64
#  8   거치대수_QR    2653 non-null   float64
#  9   운영방식       2653 non-null   object
#  10  총 거치대수     2653 non-null   float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 228.1+ KB
# None

# %%
bike_Stop.head()
# Out:
#    대여소번호   보관소(대여소)명  자치구               상세주소         위도          경도  \
# 0    102  망원역 1번출구 앞  마포구  서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 1    103  망원역 2번출구 앞  마포구  서울특별시 마포구 월드컵로 79  37.554951  126.910835
# 2    104  합정역 1번출구 앞  마포구   서울특별시 마포구 양화로 59  37.550629  126.914986
# 3    105  합정역 5번출구 앞  마포구   서울특별시 마포구 양화로 48  37.550007  126.914825
# 4    106  합정역 7번출구 앞  마포구    서울특별시 마포구 독막로 4  37.548645  126.912826
#
#         설치시기  거치대수_LCD  거치대수_QR 운영방식  총 거치대수
# 0   2022.5.3       NaN     15.0   QR     NaN
# 1   2022.5.3       NaN     14.0   QR     NaN
# 2  2022.5.12       NaN     13.0   QR     NaN
# 3   2015.9.6       NaN      5.0   QR     NaN
# 4  2022.5.12       NaN     12.0   QR     NaN

# %%
# 자치구 별로 value 정렬
bike_Stop_borough = bike_Stop.sort_values(by="자치구", ascending=True) 

# index 다시 설정
bike_Stop_borough = bike_Stop_borough.reset_index(drop=True)

bike_Stop_borough.head()
# Out:
#    대여소번호               보관소(대여소)명  자치구                상세주소         위도  \
# 0   2354                청담역 2번출구  강남구  서울특별시 강남구 영동대로 647  37.519787
# 1   2390  구룡마을 입구 (래미안블레스티지 아파트)  강남구       강남구 개포동 146-1  37.480881
# 2   2392   구룡산 입구 (구룡산 서울둘레길 입구)  강남구        강남구 개포동 1277  37.474472
# 3   2393        구룡사 앞 교차로 (보도육교)  강남구        강남구 개포동 1277  37.472000
# 4   2394     개포래미안포레스트아파트 107동 앞  강남구         강남구 개포로 264  37.480297
#
#            경도        설치시기  거치대수_LCD  거치대수_QR 운영방식  총 거치대수
# 0  127.056763   2017.8.21       5.0      NaN  LCD     NaN
# 1  127.063042   2018.10.8      10.0      NaN  LCD     NaN
# 2  127.055450   2018.10.8      15.0      NaN  LCD     NaN
# 3  127.051338   2018.10.8      10.0      NaN  LCD     NaN
# 4  127.054260  2020.12.11       NaN     10.0   QR     NaN

# %%
bike_Stop.count() # 총 2653 개
# Out:
# 대여소번호        2653
# 보관소(대여소)명    2653
# 자치구          2653
# 상세주소         2653
# 위도           2653
# 경도           2653
# 설치시기         2652
# 거치대수_LCD     1290
# 거치대수_QR      1378
# 운영방식         2653
# 총 거치대수         16
# dtype: int64

# %%
bike_Stop_location = bike_Stop_borough[['위도','경도']]
print(bike_Stop_location.head(5))
# Out:
#           위도          경도
# 0  37.519787  127.056763
# 1  37.480881  127.063042
# 2  37.474472  127.055450
# 3  37.472000  127.051338
# 4  37.480297  127.054260

# %%
#자치구 별 대여소 개수
borough = bike_Stop['자치구'].value_counts()
print(borough)
# Out:
# 송파구     209
# 강서구     184
# 강남구     159
# 영등포구    146
# 서초구     141
# 노원구     127
# 마포구     122
# 강동구     119
# 종로구     106
# 양천구     106
# 구로구     104
# 중랑구      95
# 은평구      95
# 용산구      88
# 성동구      87
# 광진구      86
# 중구       86
# 동대문구     82
# 성북구      81
# 서대문구     79
# 관악구      76
# 금천구      74
# 도봉구      72
# 동작구      71
# 강북구      58
# Name: 자치구, dtype: int64

# %%
borough.min() # 강북구
# Out:
# 58

# %%
borough.max() # 송파구
# Out:
# 209

# %%
#자치구 별 groupby 
borough_grouped = bike_Stop_borough.groupby(['자치구'])

for key, group in borough_grouped:
    print('* 자치구 :', key)
    print('* 개수 :', len(group)) 
    print(group.head())
    print('\n')
# Out:
# * 자치구 : 강남구
# * 개수 : 159
#    대여소번호               보관소(대여소)명  자치구                상세주소         위도  \
# 0   2354                청담역 2번출구  강남구  서울특별시 강남구 영동대로 647  37.519787
# 1   2390  구룡마을 입구 (래미안블레스티지 아파트)  강남구       강남구 개포동 146-1  37.480881
# 2   2392   구룡산 입구 (구룡산 서울둘레길 입구)  강남구        강남구 개포동 1277  37.474472
# 3   2393        구룡사 앞 교차로 (보도육교)  강남구        강남구 개포동 1277  37.472000
# 4   2394     개포래미안포레스트아파트 107동 앞  강남구         강남구 개포로 264  37.480297
#
#            경도        설치시기  거치대수_LCD  거치대수_QR 운영방식  총 거치대수
# 0  127.056763   2017.8.21       5.0      NaN  LCD     NaN
# 1  127.063042   2018.10.8      10.0      NaN  LCD     NaN
# 2  127.055450   2018.10.8      15.0      NaN  LCD     NaN
# 3  127.051338   2018.10.8      10.0      NaN  LCD     NaN
# 4  127.054260  2020.12.11       NaN     10.0   QR     NaN
#
#
# * 자치구 : 강동구
# * 개수 : 119
#      대여소번호      보관소(대여소)명  자치구              상세주소         위도          경도  \
# 159   1037     강일리버파크 6단지  강동구   서울특별시 강일동 448-2  37.562565  127.177612
# ...

# %%
borough = bike_Stop['자치구'].value_counts()

borough = borough.reset_index()
borough.columns = ['자치구','대여소 수']
borough= borough.set_index('자치구')
borough
# Out:
#       대여소 수
# 자치구
# 송파구     209
# 강서구     184
# 강남구     159
# 영등포구    146
# 서초구     141
# 노원구     127
# 마포구     122
# 강동구     119
# 종로구     106
# 양천구     106
# 구로구     104
# 중랑구      95
# 은평구      95
# 용산구      88
# 성동구      87
# 광진구      86
# 중구       86
# 동대문구     82
# 성북구      81
# 서대문구     79
# 관악구      76
# 금천구      74
# 도봉구      72
# 동작구      71
# 강북구      58

# %%
import folium
import json

lat = bike_Stop['위도'].mean()
lng = bike_Stop['경도'].mean()
s_geo = '02. skorea_municipalities_geo_simple.json'
s_str = json.load(open(s_geo, encoding="utf-8"))
s_map = folium.Map(location= [lat,lng],zoom_start=11)

s_map.choropleth(
    geo_data = s_str,
    data = borough['대여소 수'],
    columns=['자치구', '대여소 수'],
    fill_color='Accent', fill_opacity=0.7, line_opacity=0.3,
    key_on='feature.properties.name'
)
s_map
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/folium/folium.py:407: FutureWarning:
#
# The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
borough_region = borough_grouped['총 거치대수'].sum().reset_index()

borough_region = borough_region.set_index('자치구')

borough_region.sort_values(by='총 거치대수', ascending=False)
# Out:
#       총 거치대수
# 자치구
# 마포구    137.0
# 서대문구    76.0
# 강서구     51.0
# 동대문구    30.0
# 종로구     30.0
# 송파구     30.0
# 강동구     27.0
# 성동구     25.0
# 구로구     22.0
# 강남구     20.0
# 은평구     19.0
# 도봉구      0.0
# 동작구      0.0
# 노원구      0.0
# 금천구      0.0
# 서초구      0.0
# 광진구      0.0
# 성북구      0.0
# 관악구      0.0
# 양천구      0.0
# 영등포구     0.0
# 용산구      0.0
# 강북구      0.0
# 중구       0.0
# 중랑구      0.0

# %%
import folium
import json

lat = bike_Stop['위도'].mean()
lng = bike_Stop['경도'].mean()

#s_geo='https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'

s_geo = '02. skorea_municipalities_geo_simple.json'
s_str = json.load(open(s_geo, encoding="utf-8"))
s_map = folium.Map(location= [lat,lng],zoom_start=11)

s_map.choropleth(
    geo_data = s_str,
    data = borough_region['총 거치대수'],
    columns=['자치구', '총 거치대수'],
    fill_color='PuRd', fill_opacity=0.7, line_opacity=0.3,
    key_on='feature.properties.name'
)

s_map
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/folium/folium.py:407: FutureWarning:
#
# The choropleth  method has been deprecated. Instead use the new Choropleth class, which has the same arguments. See the example notebook 'GeoJSON_and_choropleth' for how to do this.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
# ...

# %%
# 자치구 별 최소 대여소 설치 구는 강북구 (58개)
borough_min = borough_grouped.get_group('강북구')
print(borough_min)
# Out:
#      대여소번호            보관소(대여소)명  자치구                   상세주소         위도  \
# 278   1547             꿈의숲 롯데캐슬  강북구           강북구 미아동 1-46  37.618641
# 279   1503        이디야 커피 수유역점 앞  강북구      서울특별시 강북구 도봉로 355  37.639263
# 280   1538                솔밭공원역  강북구      서울특별시 강북구 삼양로 595  37.656158
# 281   1539            4.19민주묘지역  강북구      서울특별시 강북구 삼양로 519  37.649673
# 282   1540                 가오리역  강북구      서울특별시 강북구 삼양로 426  37.641670
# 283   1541                  삼양역  강북구      서울특별시 강북구 삼양로 263  37.626530
# 284   1542               삼양사거리역  강북구      서울특별시 강북구 삼양로 197  37.621552
# 285   1543            수유1동 주민센터  강북구      서울특별시 강북구 삼양로 299  37.630188
# 286   1546               송천동우체국  강북구          강북구 미아동 861-1  37.615459
# 287   1548           북서울 꿈의숲 서문  강북구             강북구 번동 123  37.622688
# 288   1557                  신창교  강북구           강북구 번동 612-3  37.632381
# 289   1551              4.19탑 앞  강북구             수유동 567-69  37.646862
# ...

# %%
import folium 

bike_lat = borough_min['위도'].mean()
bike_lng = borough_min['경도'].mean()

m = folium.Map([bike_lat, bike_lng], zoom_start=14)

for name, lat, lng in zip(borough_min['보관소(대여소)명'], borough_min['위도'], borough_min['경도']):
    folium.Marker([lat,lng],
                    icon=folium.Icon(color='orange'),
                    popup=name
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# 자치구 별 최대 대여소 설치 구는 송파구 (206개)
borough_max = borough_grouped.get_group('송파구')
print(borough_max)
# Out:
#       대여소번호          보관소(대여소)명  자치구                     상세주소         위도  \
# 1722   1235       잠실트리지움310동 옆  송파구         서울특별시 송파구 잠실로 62  37.508873
# 1723   1240           문정 법조단지4  송파구         서울특별시 송파구 새말로 62  37.480576
# 1724   1239           문정 법조단지3  송파구         서울특별시 송파구 정의로 30  37.480843
# 1725   1233     잠실3거리(갤러리아팰리스)  송파구  서울특별시 송파구 석촌호수로12길 3-17  37.510509
# 1726   1232      잠실주공 521동 건너편  송파구  서울특별시 송파구 석촌호수로12길 3-19  37.512089
# ...     ...                ...  ...                      ...        ...
# 1926   4463          방이역 2번 출구  송파구                    오금동43  37.508015
# 1927   4464          올림픽공원 북2문  송파구                 방이동88-16  37.523575
# 1928   4465         건영아파트앞 사거리  송파구                   문정동 72  37.482456
# 1929   4473   마천금호어울림 1차 102동앞  송파구                  성내천로245  37.498089
# 1930   4490  송파파인타운 10단지 1005동  송파구                송파대로8길 20  37.477783
#
#               경도        설치시기  거치대수_LCD  거치대수_QR 운영방식  총 거치대수
# ...

# %%
import folium 

bike_lat = borough_max['위도'].mean()
bike_lng = borough_max['경도'].mean()

m = folium.Map([bike_lat, bike_lng], zoom_start=13)

for name, lat, lng in zip(borough_max['보관소(대여소)명'], borough_max['위도'], borough_max['경도']):
    folium.Marker([lat,lng],
                   icon=folium.Icon(color='orange'),
                    popup=name
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
import pandas as pd
bike_use = pd.read_csv('서울특별시 공공자전거 이용정보(월별)_22.06..csv',encoding='CP949')

bike_use.head()
# Out:
#       대여일자  대여소번호  대여소명   대여구분코드  성별 연령대코드  이용건수     운동량   탄소량   이동거리(M)  \
# 0  2022-06      3  중랑센터  일일(비회원)  \N    기타     1   29.34  0.26   1140.00
# 1  2022-06      3  중랑센터   일일(회원)   M   50대    19  458.11  4.44  19280.00
# 2  2022-06      3  중랑센터       정기  \N   20대    12  330.13  3.39  14626.81
# 3  2022-06      3  중랑센터       정기  \N   60대     4  113.53  1.02   4410.69
# 4  2022-06      3  중랑센터       정기   M   20대     2   13.69  0.07    320.00
#
#    이용시간(분)
# 0        6
# 1      117
# 2       75
# 3       22
# 4        4

# %%
bike_use.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 133101 entries, 0 to 133100
# Data columns (total 11 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   대여일자     133101 non-null  object
#  1   대여소번호    133101 non-null  int64
#  2   대여소명     133101 non-null  object
#  3   대여구분코드   133101 non-null  object
#  4   성별       116189 non-null  object
#  5   연령대코드    133101 non-null  object
#  6   이용건수     133101 non-null  int64
#  7   운동량      133101 non-null  object
#  8   탄소량      133101 non-null  object
#  9   이동거리(M)  133101 non-null  float64
#  10  이용시간(분)  133101 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 11.2+ MB

# %%
bike_use.describe()
# Out:
#                대여소번호           이용건수       이동거리(M)        이용시간(분)
# count  133101.000000  133101.000000  1.331010e+05  133101.000000
# mean     2133.390733      31.980917  8.726781e+04     729.954516
# std      1560.201091      63.226084  1.740702e+05    1415.938446
# min         3.000000       1.000000  0.000000e+00       0.000000
# 25%       906.000000       3.000000  8.238770e+03      76.000000
# 50%      1826.000000      10.000000  2.859469e+04     249.000000
# 75%      3509.000000      33.000000  9.287133e+04     792.000000
# max     99999.000000    1952.000000  7.781742e+06   78879.000000

# %%
bike_use = bike_use.drop(['대여구분코드','운동량','탄소량'],axis=1)

bike_use.head()
# Out:
#       대여일자  대여소번호  대여소명  성별 연령대코드  이용건수   이동거리(M)  이용시간(분)
# 0  2022-06      3  중랑센터  \N    기타     1   1140.00        6
# 1  2022-06      3  중랑센터   M   50대    19  19280.00      117
# 2  2022-06      3  중랑센터  \N   20대    12  14626.81       75
# 3  2022-06      3  중랑센터  \N   60대     4   4410.69       22
# 4  2022-06      3  중랑센터   M   20대     2    320.00        4

# %%
bike_use['성별'].unique()
# Out:
# array(['\\N', 'M', 'F', nan, 'm', 'f'], dtype=object)

# %%
bike_use[bike_use['성별'] == 'f'] = 'F'
bike_use[bike_use['성별'] == 'm'] = 'M'

bike_use['성별'].unique()
# Out:
# array(['\\N', 'M', 'F', nan], dtype=object)

# %%
# bike_use 데이터의 대여소명 앞의 숫자가 삭제된 새로운 데이터 칼럼 생성
bike_use['대여소명_new'] = bike_use['대여소명'].str.split('.', expand=True)[1]

print(bike_use.shape)
print(bike_use.isnull().sum())

bike_use.head()
# Out:
# (133012, 9)
# 대여일자            0
# 대여소번호           0
# 대여소명            0
# 성별          16907
# 연령대코드           0
# 이용건수            0
# 이동거리(M)         0
# 이용시간(분)         0
# 대여소명_new        0
# dtype: int64
#        대여일자 대여소번호             대여소명  성별 연령대코드 이용건수   이동거리(M) 이용시간(분)  \
# 11  2022-06   102  102. 망원역 1번출구 앞  \N   10대    3   5653.27     110
# 12  2022-06   102  102. 망원역 1번출구 앞  \N   20대    9  28401.76     284
# 13  2022-06   102  102. 망원역 1번출구 앞  \N   50대    3   7960.04     125
# 14  2022-06   102  102. 망원역 1번출구 앞   F   10대    1   4681.84      82
# 15  2022-06   102  102. 망원역 1번출구 앞   F   20대    5  17622.86     152
#
#        대여소명_new
# 11   망원역 1번출구 앞
# 12   망원역 1번출구 앞
# 13   망원역 1번출구 앞
# 14   망원역 1번출구 앞
# 15   망원역 1번출구 앞

# %%
bike_use = bike_use.dropna(subset=['대여소명_new'])

print(bike_use.shape)
print(bike_use.isnull().sum())
# Out:
# (133012, 9)
# 대여일자            0
# 대여소번호           0
# 대여소명            0
# 성별          16907
# 연령대코드           0
# 이용건수            0
# 이동거리(M)         0
# 이용시간(분)         0
# 대여소명_new        0
# dtype: int64

# %%
print(bike_use.shape)
print(bike_use.isnull().sum())
# Out:
# (133012, 9)
# 대여일자            0
# 대여소번호           0
# 대여소명            0
# 성별          16907
# 연령대코드           0
# 이용건수            0
# 이동거리(M)         0
# 이용시간(분)         0
# 대여소명_new        0
# dtype: int64

# %%
bike_use1 = bike_use.dropna()

bike_use1.head(20)
# Out:
#        대여일자 대여소번호             대여소명  성별 연령대코드 이용건수   이동거리(M) 이용시간(분)
# 0   2022-06     3             중랑센터  \N    기타    1    1140.0       6
# 1   2022-06     3             중랑센터   M   50대   19   19280.0     117
# 2   2022-06     3             중랑센터  \N   20대   12  14626.81      75
# 3   2022-06     3             중랑센터  \N   60대    4   4410.69      22
# 4   2022-06     3             중랑센터   M   20대    2     320.0       4
# 5   2022-06     3             중랑센터   M   40대   12  19557.91     120
# 6   2022-06     3             중랑센터   M   50대   12  24518.37     293
# 7   2022-06     3             중랑센터   M   60대    4   5078.18     147
# 8   2022-06     3             중랑센터   M    기타    1    8690.0      41
# 9   2022-06     5         상암센터 정비실   M   40대   15  58430.19     329
# 10  2022-06     5         상암센터 정비실  \N   40대    1   12110.0      54
# 11  2022-06   102  102. 망원역 1번출구 앞  \N   10대    3   5653.27     110
# 12  2022-06   102  102. 망원역 1번출구 앞  \N   20대    9  28401.76     284
# ...

# %%
bike_use['성별'].value_counts()
# Out:
# M     40701
# \N    38510
# F     36978
# Name: 성별, dtype: int64

# %%
bike_use_Sex = bike_use['성별'].value_counts().reset_index()

bike_use_Sex = bike_use_Sex.drop(1)

bike_use_Sex.index = [0,1]
bike_use_Sex.columns = ['성별','이용 수']

bike_use_Sex
# Out:
#   성별   이용 수
# 0  M  40701
# 1  F  36978

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(font="AppleGothic", 
        rc={"axes.unicode_minus":False},
        style='darkgrid')

# %%
palette1 = sns.color_palette('PuRd',10)

sns.palplot(palette1)

# %%
palette2 = sns.color_palette('colorblind',10)

sns.palplot(palette2)

# %%
palette3 = sns.color_palette('coolwarm',10)

sns.palplot(palette3)

# %%
palette4 = sns.color_palette('Set2',10)

sns.palplot(palette4)

# %%
sns.countplot(data=bike_use, x='성별',palette=palette2)
# Out:
# <AxesSubplot: xlabel='성별', ylabel='count'>

# %%
bike_use["연령대코드"].value_counts()

bike_use_Age = bike_use["연령대코드"].value_counts().reset_index()
bike_use_Age.columns = ["연령대", "이용 수"]

bike_use_Age
# Out:
#      연령대   이용 수
# 0    20대  23524
# 1    30대  21465
# 2    40대  20912
# 3     기타  18963
# 4    10대  16987
# 5    50대  16825
# 6    60대  10627
# 7  70대이상   3779
# 8      M     13
# 9      F      6

# %%
sns.countplot(data=bike_use, x='연령대코드',palette=palette1,
            order=bike_use['연령대코드'].value_counts().index)
# Out:
# <AxesSubplot: xlabel='연령대코드', ylabel='count'>

# %%
bike_stationUse = pd.read_csv('서울특별시 공공자전거 대여소별 이용정보(월별)_22.06.csv',encoding='CP949')

bike_stationUse.head()
# Out:
#                      대여소 명  대여 건수  대여일자/월
# 0  2391. 구룡터널 입구(개포1단지아파트)      4  202206
# 1           5082. 가양역 7번출구      5  202206
# 2          4719. 종로문화원 건너편     24  202206
# 3          3527. 왕십리 자이아파트     25  202206
# 4       4314. 탑성마을 버스정거장 옆     29  202206

# %%
bike_stationUse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2627 entries, 0 to 2626
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   대여소 명   2627 non-null   object
#  1   대여 건수   2627 non-null   int64
#  2   대여일자/월  2627 non-null   int64
# dtypes: int64(2), object(1)
# memory usage: 61.7+ KB

# %%
bike_stationUse.describe()
# Out:
#               대여 건수    대여일자/월
# count   2627.000000    2627.0
# mean    1620.684812  202206.0
# std     1439.102130       0.0
# min        4.000000  202206.0
# 25%      675.500000  202206.0
# 50%     1235.000000  202206.0
# 75%     2160.000000  202206.0
# max    16498.000000  202206.0

# %%
bike_stationUse.isnull().sum()
# Out:
# 대여소 명     0
# 대여 건수     0
# 대여일자/월    0
# dtype: int64

# %%
#bike_stationUse 의 대여소번호 명 앞 숫자 분리
bike_stationUse['대여소번호'] = bike_stationUse['대여소 명'].str.split('.',expand=True)[0]

#대여소명은 숫자를 분리한 새로운 칼럼 값으로 지정
bike_stationUse['대여소명_new']  = bike_stationUse['대여소 명'].str.split('.',expand=True)[1]

print(bike_stationUse.shape)
print(bike_stationUse.isnull().sum())
# Out:
# (2627, 5)
# 대여소 명       0
# 대여 건수       0
# 대여일자/월      0
# 대여소번호       0
# 대여소명_new    0
# dtype: int64

# %%
bike_stationUse.head()
# Out:
#                      대여소 명  대여 건수  대여일자/월  대여소번호            대여소명_new
# 0  2391. 구룡터널 입구(개포1단지아파트)      4  202206   2391   구룡터널 입구(개포1단지아파트)
# 1           5082. 가양역 7번출구      5  202206   5082            가양역 7번출구
# 2          4719. 종로문화원 건너편     24  202206   4719           종로문화원 건너편
# 3          3527. 왕십리 자이아파트     25  202206   3527           왕십리 자이아파트
# 4       4314. 탑성마을 버스정거장 옆     29  202206   4314        탑성마을 버스정거장 옆

# %%
#대여소번호를 수치형 데이터로 변경
bike_Stop['대여소번호'] = pd.to_numeric(bike_Stop['대여소번호'])

bike_stationUse['대여소번호'] = pd.to_numeric(bike_stationUse['대여소번호'])

bike_Stop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2653 entries, 0 to 2652
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소번호      2653 non-null   int64
#  1   보관소(대여소)명  2653 non-null   object
#  2   자치구        2653 non-null   object
#  3   상세주소       2653 non-null   object
#  4   위도         2653 non-null   float64
#  5   경도         2653 non-null   float64
#  6   설치시기       2652 non-null   object
#  7   거치대수_LCD   1290 non-null   float64
#  8   거치대수_QR    1378 non-null   float64
#  9   운영방식       2653 non-null   object
# dtypes: float64(4), int64(1), object(5)
# memory usage: 207.4+ KB

# %%
bike_merge = pd.merge(bike_Stop, bike_stationUse, left_on='대여소번호', right_on='대여소번호')

bike_merge.head()
# Out:
#    대여소번호   보관소(대여소)명  자치구               상세주소         위도          경도  \
# 0    102  망원역 1번출구 앞  마포구  서울특별시 마포구 월드컵로 72  37.555649  126.910629
# 1    103  망원역 2번출구 앞  마포구  서울특별시 마포구 월드컵로 79  37.554951  126.910835
# 2    104  합정역 1번출구 앞  마포구   서울특별시 마포구 양화로 59  37.550629  126.914986
# 3    105  합정역 5번출구 앞  마포구   서울특별시 마포구 양화로 48  37.550007  126.914825
# 4    106  합정역 7번출구 앞  마포구    서울특별시 마포구 독막로 4  37.548645  126.912826
#
#         설치시기  거치대수_LCD  거치대수_QR 운영방식  총 거치대수            대여소 명  대여 건수  대여일자/월  \
# 0   2022.5.3       0.0     15.0   QR    15.0  102. 망원역 1번출구 앞   4893  202206
# 1   2022.5.3       0.0     14.0   QR    14.0  103. 망원역 2번출구 앞   3861  202206
# 2  2022.5.12       0.0     13.0   QR    13.0  104. 합정역 1번출구 앞   2037  202206
# 3   2015.9.6       0.0      5.0   QR     5.0  105. 합정역 5번출구 앞   1414  202206
# 4  2022.5.12       0.0     12.0   QR    12.0  106. 합정역 7번출구 앞   4102  202206
#
#       대여소명_new
# 0   망원역 1번출구 앞
# 1   망원역 2번출구 앞
# 2   합정역 1번출구 앞
# 3   합정역 5번출구 앞
# ...

# %%
#필요한 칼럼만 추출
bike_merge1 = bike_merge[['대여소번호','보관소(대여소)명','자치구','총 거치대수','대여 건수','대여일자/월']]

bike_merge1.head()
bike_merge1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2623 entries, 0 to 2622
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   대여소번호      2623 non-null   int64
#  1   보관소(대여소)명  2623 non-null   object
#  2   자치구        2623 non-null   object
#  3   총 거치대수     2623 non-null   float64
#  4   대여 건수      2623 non-null   int64
#  5   대여일자/월     2623 non-null   int64
# dtypes: float64(1), int64(3), object(2)
# memory usage: 143.4+ KB

# %%
#자치구 별 대여건수 확인

bike_merge1_group = bike_merge1.groupby('자치구')['대여 건수'].sum().reset_index()
bike_merge1_group= bike_merge1_group.set_index('자치구')

bike_merge1_group
# Out:
#        대여 건수
# 자치구
# 강남구   123824
# 강동구   189847
# 강북구    63244
# 강서구   483305
# 관악구   121677
# 광진구   203223
# 구로구   162797
# 금천구    71295
# 노원구   244290
# 도봉구    89057
# 동대문구  150391
# 동작구    91624
# 마포구   230808
# 서대문구   90544
# 서초구   127726
# 성동구   159445
# 성북구   109680
# 송파구   397680
# 양천구   247777
# 영등포구  330691
# 용산구    94644
# 은평구   111689
# 종로구   136366
# 중구     93993
# 중랑구   122772

# %%
bike_merge1_group.sort_values(by='대여 건수', ascending=False)

bike_merge1_group.head()
# Out:
#       대여 건수
# 자치구
# 강남구  123824
# 강동구  189847
# 강북구   63244
# 강서구  483305
# 관악구  121677

# %%
import folium
import json

lat = bike_Stop['위도'].mean()
lng = bike_Stop['경도'].mean()
s_geo = '02. skorea_municipalities_geo_simple.json'
s_str = json.load(open(s_geo, encoding="utf-8"))
s_map = folium.Map(location= [lat,lng],zoom_start=11)

s_map.choropleth(
    geo_data = s_str,
    data = bike_merge1_group['대여 건수'],
    columns=['자치구', '대여 건수'],
    fill_color='Spectral', fill_opacity=0.7, line_opacity=0.3,
    key_on='feature.properties.name'
)
s_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
bike_new = pd.read_csv('서울특별시 공공자전거 신규가입자 정보(월별)_22.01~22.06.csv',encoding='CP949')

bike_new.head()
# Out:
#      가입일시   사용자코드 연령대코드 성별  가입 수
# 0  202201  회원-내국인   10대  F   112
# 1  202201  회원-내국인   10대  F   997
# 2  202201  회원-내국인   10대  M    89
# 3  202201  회원-내국인   10대  M  1264
# 4  202201  회원-내국인   20대  F   198

# %%
bike_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   가입일시    188 non-null    int64
#  1   사용자코드   188 non-null    object
#  2   연령대코드   188 non-null    object
#  3   성별      188 non-null    object
#  4   가입 수    188 non-null    int64
# dtypes: int64(2), object(3)
# memory usage: 7.5+ KB

# %%
bike_new.describe()
# Out:
#                 가입일시          가입 수
# count     188.000000    188.000000
# mean   202203.521277   1759.414894
# std         1.716412   3589.392600
# min    202201.000000      1.000000
# 25%    202202.000000     82.250000
# 50%    202204.000000    224.500000
# 75%    202205.000000   1335.000000
# max    202206.000000  20097.000000

# %%
bike_new_group1 = bike_new.groupby('가입일시')

for key, group in bike_new_group1:
    print('* 가입일시 :', key)
    print('* 가입 수 :', len(group)) 
    print(group.head())
    print('\n')
# Out:
# * 가입일시 : 202201
# * 가입 수 : 31
#      가입일시   사용자코드 연령대코드 성별  가입 수
# 0  202201  회원-내국인   10대  F   112
# 1  202201  회원-내국인   10대  F   997
# 2  202201  회원-내국인   10대  M    89
# 3  202201  회원-내국인   10대  M  1264
# 4  202201  회원-내국인   20대  F   198
#
#
# * 가입일시 : 202202
# * 가입 수 : 31
#       가입일시   사용자코드 연령대코드 성별  가입 수
# 31  202202  회원-내국인   10대  F   122
# 32  202202  회원-내국인   10대  F  1416
# 33  202202  회원-내국인   10대  M    85
# 34  202202  회원-내국인   10대  M  1704
# 35  202202  회원-내국인   20대  F   236
#
#
# * 가입일시 : 202203
# * 가입 수 : 31
#       가입일시   사용자코드 연령대코드 성별  가입 수
# 62  202203  회원-내국인   10대  F   162
# 63  202203  회원-내국인   10대  F  2690
# 64  202203  회원-내국인   10대  M   131
# 65  202203  회원-내국인   10대  M  3069
# 66  202203  회원-내국인   20대  F   290
#
#
# * 가입일시 : 202204
# * 가입 수 : 31
#       가입일시   사용자코드 연령대코드 성별  가입 수
# 93  202204  회원-내국인   10대  F   160
# 94  202204  회원-내국인   10대  F  4820
# 95  202204  회원-내국인   10대  M   137
# 96  202204  회원-내국인   10대  M  5824
# 97  202204  회원-내국인   20대  F   455
#
# ...

# %%
bike_new_group_202206 = bike_new_group1.get_group(202206)
bike_new_group_202206.reset_index(drop=True,inplace=True)

bike_new_group_202206.drop(['사용자코드'],axis=1,inplace=True)

bike_new_group_202206.head()
# Out:
# /var/folders/wz/l853nscd7z14qvxxhg47dns40000gn/T/ipykernel_3492/1962645218.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bike_new_group_202206.drop(['사용자코드'],axis=1,inplace=True)
#      가입일시 연령대코드 성별  가입 수
# 0  202206   10대  F   231
# 1  202206   10대  F  3251
# 2  202206   10대  M   210
# 3  202206   10대  M  4802
# 4  202206   20대  F   633

# %%
bike_new['성별'].value_counts()
# Out:
# M    95
# F    93
# Name: 성별, dtype: int64

# %%
sns.countplot(data=bike_new, x='성별')
# Out:
# <AxesSubplot: xlabel='성별', ylabel='count'>

# %%
bike_new_group_202206['성별'].value_counts()
# Out:
# F    16
# M    16
# Name: 성별, dtype: int64

# %%
sns.countplot(data=bike_new_group_202206, x='성별')
# Out:
# <AxesSubplot: xlabel='성별', ylabel='count'>

# %%
sns.barplot(data=bike_new_group_202206, x='연령대코드',y='가입 수',hue='성별',palette=palette4)
# Out:
# <AxesSubplot: xlabel='연령대코드', ylabel='가입 수'>
